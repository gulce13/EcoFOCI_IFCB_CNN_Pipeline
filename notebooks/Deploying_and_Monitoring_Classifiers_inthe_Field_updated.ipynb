# %% [markdown]
# ## **Deploying and Monitoring Classifiers in the Field**

# %% [markdown]
# #PIPELINE to use classifier during the Cruise <br>
# 1-Convert roi to png (you will need pyifcb environment for this step)<br>
# 2-Export image file paths as CSV files<br>
# 3-Process the images for tensorflow classifier <br>
# 4-Load and apply the classifier<br>
# 5-Plot 20 random images and predicted labels with and without detritus<br>
# 6-Merge the classified CSV files for a day <br>
# 7-Summarize the counts of groups per day

# %% [markdown]
# **Necessary Packages for this Workflow**

# %% [markdown]
# pip install git+https://github.com/joefutrelle/pyifcb #you will need a Python 3.10.12 environment to upload pyifcb package (import ifcb) ,it doesnt work with new versions<br>
# Python version: 3.10.12 | packaged by Anaconda, Inc. |<br>
# numpy: 1.26.4<br>
# pandas: 2.2.3<br>
# numpy: 1.26.4<br>
# pandas: 2.2.3<br>
# opencv: 4.10.0<br>
# tensorflow: 2.17.0<br>
# sklearn: 1.6.1<br>
# PIL: 10.3.0

# %% [markdown]
# ### **STEP-1 Convert roi to png**<br>
# This script processes .roi files in a specified directory by filtering files within a given range, where the start and end filenames must be set manually in the script. For each file, it creates a folder and converts the image data into PNG format. The images are saved with incremented filename. Any errors are logged, and the script continues with the next file. A completion message is printed when all files are processed.

# %%
#STEP 1  CONVERT ROI TO PNG 
import os
from PIL import Image
import glob
import ifcb  
import numpy as np

# Directory containing the .roi files
directory_path = r"D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621" #your folder path with roi,adc and hdr 

# Define the start and end filenames for the range you want to process
start_file = "D20250621T001728_IFCB217.roi"
end_file = "D20250621T234157_IFCB217.roi"

# Find all .roi files in the directory
all_roi_files = glob.glob(os.path.join(directory_path, '*.roi'))

# Filter the list for files within the specified range
filtered_roi_files = [file for file in all_roi_files if start_file <= os.path.basename(file) <= end_file]

# Iterate over each filtered .roi file
for roi_file in filtered_roi_files:
    try:
        # Extract the base filename (without the extension) to use as the folder name
        base_filename = os.path.splitext(os.path.basename(roi_file))[0]
        
        # Construct the path for the new folder
        new_folder_path = os.path.join(directory_path, base_filename)

        # Create the new folder if it doesn't exist
        os.makedirs(new_folder_path, exist_ok=True)

        # Open the .roi file to access the image data
        with ifcb.open_raw(roi_file) as sample_bin:
            # Iterate over each image in sample_bin.images
            for index, (image_name, image_data) in enumerate(sample_bin.images.items(), start=1):  # Start from 1
                # Ensure that image data is converted to an appropriate integer type
                if not np.issubdtype(image_data.dtype, np.integer):
                    # Convert floating-point image data to uint8 (common for images)
                    image_data = (255 * (image_data / np.max(image_data))).astype(np.uint8)
                
                # Convert the image data to a PIL Image object
                img = Image.fromarray(image_data)
                
                # Format the filename with the incremented part
                filename = f"{base_filename}.{index:05}.png"
                
                # Construct the full path for the output file within the new folder
                output_path = os.path.join(new_folder_path, filename)
                
                # Save the image
                img.save(output_path)

                # Free memory by closing the image object after saving
                img.close()  # Explicitly close the image to release resources
                del img  # Ensure the object is deleted to free up memory

        print(f"Processed and saved images for: {roi_file}")

    except Exception as e:
        # If there's an error processing a specific file, it will be logged, and the process will continue
        print(f"Error processing {roi_file}: {e}")

# Process complete
print("Processing complete for all files.")
# Out:
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T001728_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T004122_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T011425_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T013819_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T020213_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T022607_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T025002_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T031356_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T033750_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T040145_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T042539_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T044933_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T052518_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T054912_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T061306_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T063701_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T070055_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T072449_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T074844_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T081238_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T083632_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T090026_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T092421_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T094815_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T101209_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T103604_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T105958_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T112352_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T114746_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T121141_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T123535_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T130837_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T133232_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T135626_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T142020_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T144414_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T150809_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T153203_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T155557_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T161951_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T164346_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T170740_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T173134_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T175528_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T181923_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T184317_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T190711_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T193105_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T195459_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T201854_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T204248_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T211832_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T214226_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T220620_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T223015_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T225409_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T231803_IFCB217.roi
# Processed and saved images for: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T234157_IFCB217.roi
# Processing complete for all files.

# %% [markdown]
# ### **STEP-2 Export image file paths as CSV files**<br>
# This script generates CSV files for each image folder in the specified parent directory (e.g., D20250621), which contains subfolders (e.g., D20250621T001728_IFCB217, D20250621T004122_IFCB217) with PNG images. It iterates through each folder, collects the file paths of .png images, and creates a CSV file containing these paths. The CSV file is saved in the corresponding image folder. A message is printed once the CSV is saved for each folder.

# %%
# STEP 2- MAKE THE CSV FILES
#Parent directory, make csv file of each image folder 
import os
import pandas as pd

# Define the parent directory containing the folders
parent_dir = r"D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621" #your folder path with parent directory (D20250621) includes each folder D20250621T001728_IFCB217 with png images   

# Iterate through each folder in the parent directory
for folder_name in os.listdir(parent_dir):
    folder_path = os.path.join(parent_dir, folder_name)

    # Ensure the path is a directory (i.e., a folder)
    if os.path.isdir(folder_path):
        # List to hold file paths
        image_paths = []

        # Iterate over the files in the folder
        for filename in os.listdir(folder_path):
            if filename.endswith(".png"):  # Assuming images are in PNG format
                img_path = os.path.join(folder_path, filename)
                image_paths.append(img_path)

        # Create a DataFrame with the image paths
        df = pd.DataFrame(image_paths, columns=['Image_Path'])

        # Define the CSV file name using the folder name
        csv_path = os.path.join(folder_path, f"{folder_name}_Image_Path.csv")
        
        # Save the DataFrame to a CSV file
        df.to_csv(csv_path, index=False)

        print(f"Image paths for folder '{folder_name}' saved to {csv_path}")
# Out:
# Image paths for folder 'D20250621T001728_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T001728_IFCB217\D20250621T001728_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T004122_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T004122_IFCB217\D20250621T004122_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T011425_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T011425_IFCB217\D20250621T011425_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T013819_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T013819_IFCB217\D20250621T013819_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T020213_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T020213_IFCB217\D20250621T020213_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T022607_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T022607_IFCB217\D20250621T022607_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T025002_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T025002_IFCB217\D20250621T025002_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T031356_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T031356_IFCB217\D20250621T031356_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T033750_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T033750_IFCB217\D20250621T033750_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T040145_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T040145_IFCB217\D20250621T040145_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T042539_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T042539_IFCB217\D20250621T042539_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T044933_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T044933_IFCB217\D20250621T044933_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T052518_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T052518_IFCB217\D20250621T052518_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T054912_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T054912_IFCB217\D20250621T054912_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T061306_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T061306_IFCB217\D20250621T061306_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T063701_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T063701_IFCB217\D20250621T063701_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T070055_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T070055_IFCB217\D20250621T070055_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T072449_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T072449_IFCB217\D20250621T072449_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T074844_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T074844_IFCB217\D20250621T074844_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T081238_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T081238_IFCB217\D20250621T081238_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T083632_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T083632_IFCB217\D20250621T083632_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T090026_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T090026_IFCB217\D20250621T090026_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T092421_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T092421_IFCB217\D20250621T092421_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T094815_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T094815_IFCB217\D20250621T094815_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T101209_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T101209_IFCB217\D20250621T101209_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T103604_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T103604_IFCB217\D20250621T103604_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T105958_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T105958_IFCB217\D20250621T105958_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T112352_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T112352_IFCB217\D20250621T112352_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T114746_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T114746_IFCB217\D20250621T114746_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T121141_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T121141_IFCB217\D20250621T121141_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T123535_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T123535_IFCB217\D20250621T123535_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T130837_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T130837_IFCB217\D20250621T130837_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T133232_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T133232_IFCB217\D20250621T133232_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T135626_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T135626_IFCB217\D20250621T135626_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T142020_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T142020_IFCB217\D20250621T142020_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T144414_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T144414_IFCB217\D20250621T144414_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T150809_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T150809_IFCB217\D20250621T150809_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T153203_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T153203_IFCB217\D20250621T153203_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T155557_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T155557_IFCB217\D20250621T155557_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T161951_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T161951_IFCB217\D20250621T161951_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T164346_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T164346_IFCB217\D20250621T164346_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T170740_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T170740_IFCB217\D20250621T170740_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T173134_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T173134_IFCB217\D20250621T173134_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T175528_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T175528_IFCB217\D20250621T175528_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T181923_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T181923_IFCB217\D20250621T181923_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T184317_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T184317_IFCB217\D20250621T184317_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T190711_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T190711_IFCB217\D20250621T190711_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T193105_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T193105_IFCB217\D20250621T193105_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T195459_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T195459_IFCB217\D20250621T195459_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T201854_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T201854_IFCB217\D20250621T201854_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T204248_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T204248_IFCB217\D20250621T204248_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T211832_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T211832_IFCB217\D20250621T211832_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T214226_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T214226_IFCB217\D20250621T214226_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T220620_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T220620_IFCB217\D20250621T220620_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T223015_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T223015_IFCB217\D20250621T223015_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T225409_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T225409_IFCB217\D20250621T225409_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T231803_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T231803_IFCB217\D20250621T231803_IFCB217_Image_Path.csv
# Image paths for folder 'D20250621T234157_IFCB217' saved to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621T234157_IFCB217\D20250621T234157_IFCB217_Image_Path.csv

# %% [markdown]
# ### **STEP-3 Process Images**<br>
# **Step 3** of the image processing has two components. **Step 3.1** defines the functions, while **Step 3.2** applies these functions to the dataset. In **Step 3.1**, the preprocess_input function resizes images to 128x128 pixels and adds padding if necessary. The process_and_save_images function processes the images by resizing them and converting them to grayscale before saving them as .npy files in a new folder. **You won’t see any output from this step** until the images are processed and saved, as it works in the background. **Step 3.2** then applies these functions to the images listed in the CSV files.

# %%
#STEP 3.1 DEFINE FUNCTIONS

#Preprocess the image and saving function
import os
import cv2
import numpy as np

def preprocess_input(image):
    fixed_size = 128  # Final image should be 128 x 128
    image_size = image.shape[:2]  # Gets the (y_dim, x_dim) for each image

    # The ratio needed to make the longest side of the image 128 pixels
    ratio = float(fixed_size) / max(image_size)

    # Calculates the new size by multiplying each dimension by the ratio
    new_size = tuple([int(x * ratio) for x in image_size])

    # Resizes the image to the new size
    img = cv2.resize(image, (new_size[1], new_size[0]))

    # Calculates the possible padding needed for the x and y dimensions
    delta_w = fixed_size - new_size[1]
    delta_h = fixed_size - new_size[0]
    top, bottom = delta_h // 2, delta_h - (delta_h // 2)
    left, right = delta_w // 2, delta_w - (delta_w // 2)

    # Makes a black border of 128x128 pixels around the image
    color = [0, 0, 0]  # RGB = 0,0,0 -> Black
    rescaled_image = cv2.copyMakeBorder(img, top, bottom, left, right, cv2.BORDER_CONSTANT, value=color)
    
    return rescaled_image

def process_and_save_images(folder_path, destination_folder):
    # Create a new destination folder for the processed images
    processed_folder_name = os.path.basename(folder_path) + "_processed"
    processed_folder_path = os.path.join(destination_folder, processed_folder_name)
    os.makedirs(processed_folder_path, exist_ok=True)

    # Iterate through each image in the folder
    for filename in os.listdir(folder_path):
        if filename.endswith(".png"):  # Assuming images are in PNG format
            img_path = os.path.join(folder_path, filename)

            # Load the image
            image = cv2.imread(img_path)

            # Check if the image was loaded successfully
            if image is None:
                print(f"Warning: Could not load image {img_path}. Skipping this file.")
                continue

            # Process the image
            processed_image = preprocess_input(image)

            # Convert the processed image to grayscale
            processed_gray = cv2.cvtColor(processed_image, cv2.COLOR_BGR2GRAY)

            # Save the processed grayscale image as an .npy file
            npy_path = os.path.join(processed_folder_path, filename.replace('.png', '.npy'))
            np.save(npy_path, processed_gray)

    print(f"Processed images saved as .npy files to {processed_folder_path}")

# %% [markdown]
# In **Step 3.2**, the defined functions from the previous step are applied to the image folders. The parent_dir is set to the folder containing subfolders with PNG images (e.g., D20250621). A new destination folder, "D20250621_class_processed", is created to store the processed images. The script then iterates through each folder, applying the process_and_save_images function to resize and convert the images to grayscale before saving them as .npy files in the new folder. **This process can take time depending on the number of images**.

# %%
#STEP 3.2 APPLY FUNCTIONS (THIS CAN TAKE TIME)

parent_dir = r"D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621" #your folder path with parent directory (D20250621) includes each folder D20250621T001728_IFCB217 with png images 

# Create the new destination directory for all processed folders
destination_folder = os.path.join(parent_dir, "D20250621_class_processed")#Change this based on folder name
os.makedirs(destination_folder, exist_ok=True)

# Iterate through each folder in the parent directory
for folder_name in os.listdir(parent_dir):
    folder_path = os.path.join(parent_dir, folder_name)

    # Ensure the path is a directory (i.e., a folder)
    if os.path.isdir(folder_path):
        print(f"Processing folder: {folder_name}")
        process_and_save_images(folder_path, destination_folder)
# Out:
# Processing folder: D20250621T001728_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T001728_IFCB217_processed
# Processing folder: D20250621T004122_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T004122_IFCB217_processed
# Processing folder: D20250621T011425_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T011425_IFCB217_processed
# Processing folder: D20250621T013819_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T013819_IFCB217_processed
# Processing folder: D20250621T020213_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T020213_IFCB217_processed
# Processing folder: D20250621T022607_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T022607_IFCB217_processed
# Processing folder: D20250621T025002_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T025002_IFCB217_processed
# Processing folder: D20250621T031356_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T031356_IFCB217_processed
# Processing folder: D20250621T033750_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T033750_IFCB217_processed
# Processing folder: D20250621T040145_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T040145_IFCB217_processed
# Processing folder: D20250621T042539_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T042539_IFCB217_processed
# Processing folder: D20250621T044933_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T044933_IFCB217_processed
# Processing folder: D20250621T052518_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T052518_IFCB217_processed
# Processing folder: D20250621T054912_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T054912_IFCB217_processed
# Processing folder: D20250621T061306_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T061306_IFCB217_processed
# Processing folder: D20250621T063701_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T063701_IFCB217_processed
# Processing folder: D20250621T070055_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T070055_IFCB217_processed
# Processing folder: D20250621T072449_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T072449_IFCB217_processed
# Processing folder: D20250621T074844_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T074844_IFCB217_processed
# Processing folder: D20250621T081238_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T081238_IFCB217_processed
# Processing folder: D20250621T083632_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T083632_IFCB217_processed
# Processing folder: D20250621T090026_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T090026_IFCB217_processed
# Processing folder: D20250621T092421_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T092421_IFCB217_processed
# Processing folder: D20250621T094815_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T094815_IFCB217_processed
# Processing folder: D20250621T101209_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T101209_IFCB217_processed
# Processing folder: D20250621T103604_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T103604_IFCB217_processed
# Processing folder: D20250621T105958_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T105958_IFCB217_processed
# Processing folder: D20250621T112352_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T112352_IFCB217_processed
# Processing folder: D20250621T114746_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T114746_IFCB217_processed
# Processing folder: D20250621T121141_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T121141_IFCB217_processed
# Processing folder: D20250621T123535_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T123535_IFCB217_processed
# Processing folder: D20250621T130837_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T130837_IFCB217_processed
# Processing folder: D20250621T133232_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T133232_IFCB217_processed
# Processing folder: D20250621T135626_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T135626_IFCB217_processed
# Processing folder: D20250621T142020_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T142020_IFCB217_processed
# Processing folder: D20250621T144414_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T144414_IFCB217_processed
# Processing folder: D20250621T150809_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T150809_IFCB217_processed
# Processing folder: D20250621T153203_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T153203_IFCB217_processed
# Processing folder: D20250621T155557_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T155557_IFCB217_processed
# Processing folder: D20250621T161951_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T161951_IFCB217_processed
# Processing folder: D20250621T164346_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T164346_IFCB217_processed
# Processing folder: D20250621T170740_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T170740_IFCB217_processed
# Processing folder: D20250621T173134_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T173134_IFCB217_processed
# Processing folder: D20250621T175528_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T175528_IFCB217_processed
# Processing folder: D20250621T181923_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T181923_IFCB217_processed
# Processing folder: D20250621T184317_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T184317_IFCB217_processed
# Processing folder: D20250621T190711_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T190711_IFCB217_processed
# Processing folder: D20250621T193105_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T193105_IFCB217_processed
# Processing folder: D20250621T195459_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T195459_IFCB217_processed
# Processing folder: D20250621T201854_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T201854_IFCB217_processed
# Processing folder: D20250621T204248_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T204248_IFCB217_processed
# Processing folder: D20250621T211832_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T211832_IFCB217_processed
# Processing folder: D20250621T214226_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T214226_IFCB217_processed
# Processing folder: D20250621T220620_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T220620_IFCB217_processed
# Processing folder: D20250621T223015_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T223015_IFCB217_processed
# Processing folder: D20250621T225409_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T225409_IFCB217_processed
# Processing folder: D20250621T231803_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T231803_IFCB217_processed
# Processing folder: D20250621T234157_IFCB217
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621T234157_IFCB217_processed
# Processing folder: D20250621_class_processed
# Processed images saved as .npy files to D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\D20250621_class_processed_processed

# %% [markdown]
# ### **STEP-4 Load and Apply the Classifier**<br>
# **Step 4** applies the EcoFOCI_v2 model (Classifier EcoFOCI batch) with input normalization added. It begins by loading the pre-trained model and label encoder. The model processes each folder containing the processed .npy images, normalizes the image data, and ensures that the images have the correct shape for prediction. After prediction, the script retrieves the predicted class, assigns labels, and calculates prediction scores. These results, including the image paths, predicted labels, and prediction scores, are then saved as CSV files in a new output folder. The script prints progress updates, with a final message once all folders have been processed.

# %%
#STEP 4 APPLY ECOFOCI_v2 model (Classifier EcoFOCI batch) — with input normalization added 
import os
import numpy as np
import pandas as pd
import glob
import cv2
from tensorflow.keras.models import load_model
from sklearn.preprocessing import LabelEncoder

# === Load model and label encoder ===
model_path = r"C:\Users\kurta\OneDrive - UW\Desktop\Dyson_M2\EcoFOCI_v2_20epoch_model.h5" #Pathway of CLassifier EcoFOCI batch model
model = load_model(model_path)

# Load label classes in correct order
class_labels = np.load(r"C:\Users\kurta\OneDrive - UW\Desktop\Dyson_M2\class_labels.npy", allow_pickle=True) #Label order for Classifier EcoFOCI batch model
label_encoder = LabelEncoder()
label_encoder.classes_ = class_labels

# === Base directory setup ===
parent_dir = r"D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250611\class_processed" #Pathway of your processed images(.npy files)
csv_output_folder = os.path.join(parent_dir, "classification_results_v2")#v2 means model 2 (batch model)
os.makedirs(csv_output_folder, exist_ok=True)

# === Process each *_processed folder ===
for folder_name in os.listdir(parent_dir):
    folder_path = os.path.join(parent_dir, folder_name)

    if os.path.isdir(folder_path) and folder_name.endswith("_processed"):
        print(f"\n🔍 Processing folder: {folder_name}")

        # Recursively find all .npy files
        npy_files = glob.glob(os.path.join(folder_path, '**', '*.npy'), recursive=True)

        image_data = []
        image_paths = []

        for npy_path in npy_files:
            try:
                image = np.load(npy_path)

                # ✅ Normalize to [0.0, 1.0]
                image = image.astype(np.float32) / 255.0

                # ✅ Ensure shape is (128, 128, 1)
                if image.ndim == 2:
                    image = np.expand_dims(image, axis=-1)

                # ✅ Add batch dimension
                image = np.expand_dims(image, axis=0)

                image_data.append(image)
                image_paths.append(npy_path)

            except Exception as e:
                print(f"⚠️ Error loading {npy_path}: {e}")

        if len(image_data) == 0:
            print(f"❌ No valid .npy files found in: {folder_name}. Skipping...")
            continue

        try:
            image_data = np.vstack(image_data)
        except ValueError as ve:
            print(f"❌ Error stacking images in {folder_name}: {ve}")
            continue

        # === PREDICT ===
        predictions = model.predict(image_data)  # Predictions will now be the probabilities for each class

        # Get the predicted class (index with highest probability)
        predicted_classes = np.argmax(predictions, axis=1)
        predicted_labels = label_encoder.inverse_transform(predicted_classes)

        # === SAVE TO CSV ===
        results_df = pd.DataFrame({
            'Image_Path': image_paths,
            'Predicted_Label': predicted_labels,
            'Predicted_Score': [predictions[i, predicted_classes[i]] for i in range(len(predictions))]  # Get score for the predicted class
        })

        output_csv_path = os.path.join(csv_output_folder, f"{folder_name}_classification_results_with_scores.csv")
        results_df.to_csv(output_csv_path, index=False)

        print(f"✅ Saved results to: {output_csv_path}")

# === DONE ===
print("\n🎉 Done classifying all folders.")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 🔍 Processing folder: class_processed_processed
# ❌ No valid .npy files found in: class_processed_processed. Skipping...
#
# 🔍 Processing folder: D20250611T234213_IFCB217_processed
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step
# ✅ Saved results to: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250611\class_processed\classification_results_v2\D20250611T234213_IFCB217_processed_classification_results_with_scores.csv
#
# 🔍 Processing folder: D20250612T000606_IFCB217_processed
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step
# ✅ Saved results to: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250611\class_processed\classification_results_v2\D20250612T000606_IFCB217_processed_classification_results_with_scores.csv
#
# 🎉 Done classifying all folders.

# %% [markdown]
# ### **STEP-5 Monitoring Classifier, Plots of Predicted Labels**<br>
# **Step 5** has two versions for visualizing and monitoring the classifier's predictions, **you can choose either one**:<br>
#
# **Step 5.1** plots 20 random images with their predicted labels, **including the Detritus category**. It iterates through the classification result CSV files, samples 20 random images, and displays them in a grid. Each image is shown with its predicted label. The plot is saved as a PNG file for each classification result, allowing you to visually inspect the predictions and ensure quality control (QA).<br>
#
# **Step 5.2** is similar but **excludes the Detritus category**. This step follows the same procedure as 5.1, but only the images that don't belong to the Detritus category are plotted. This allows for a more focused analysis of the classifier's performance without the presence of Detritus images.

# %%
#STEP 5.1 QA/QC PLOT PREDICTED LABELS WITH DETRITUS
##5.1 Iterate through the classified files and plot 20 images WITH DETRITUS
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Define the folder containing the classification results CSV files
classification_folder = r"D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2"#your folder path for classification results_v2 for the day D20250621 

# Iterate through each CSV file in the classification folder
for csv_file in os.listdir(classification_folder):
    if csv_file.endswith("_classification_results2.csv"):
        # Construct the full path to the CSV file
        csv_path = os.path.join(classification_folder, csv_file)
        
        # Read the CSV file
        results_df = pd.read_csv(csv_path)

        # Sample 20 random images from the DataFrame
        random_sample = results_df.sample(n=20, random_state=42)  # random_state ensures reproducibility

        # Create the plot
        plt.figure(figsize=(25, 10))

        for i, (index, row) in enumerate(random_sample.iterrows()):
            # Get the image path and predicted label
            image_path = row['Image_Path']
            predicted_label = row['Predicted_Label']

            # Load the image from the .npy file
            image = np.load(image_path)

            # Plot the image
            plt.subplot(4, 5, i + 1)  # 4 rows, 5 columns grid
            plt.imshow(image, cmap='gray')  # Assuming the image is grayscale
            plt.title(f"Predicted: {predicted_label}")
            plt.axis('off')

        plt.tight_layout()

        # Extract the base name (without the "_processed_classification_results.csv" part)
        base_name = csv_file.split("_processed_classification_results.csv")[0]

        # Define the path to save the PNG file
        output_png_path = os.path.join(classification_folder, f"{base_name}.png")

        # Save the plot as a PNG file
        plt.savefig(output_png_path)
        plt.close()  # Close the plot to free up memory

        print(f"Random 20 images plot saved as {output_png_path}")
# Out:
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T001728_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T004122_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T011425_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T013819_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T020213_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T022607_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T025002_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T031356_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T033750_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T040145_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T042539_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T044933_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T052518_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T054912_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T061306_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T063701_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T070055_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T072449_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T074844_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T081238_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T083632_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T090026_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T092421_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T094815_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T101209_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T103604_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T105958_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T112352_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T114746_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T121141_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T123535_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T130837_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T133232_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T135626_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T142020_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T144414_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T150809_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T153203_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T155557_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T161951_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T164346_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T170740_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T173134_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T175528_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T181923_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T184317_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T190711_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T193105_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T195459_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T201854_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T204248_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T211832_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T214226_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T220620_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T223015_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T225409_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T231803_IFCB217_processed_classification_results2.csv.png
# Random 20 images plot saved as D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2\D20250621T234157_IFCB217_processed_classification_results2.csv.png

# %%
#STEP 5.2 QA/QC PLOT PREDICTED LABELS WITHOUT DETRITUS
##5.2 Iterate through the classified files and plot 20 images WITHOUT DETRITUS
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Define the folder containing the classification results CSV files
classification_folder = r"D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2" #your folder path for classification results_v2 for the day D20250621

# Iterate through each CSV file in the classification folder
for csv_file in os.listdir(classification_folder):
    if csv_file.endswith("_classification_results.csv"):
        # Construct the full path to the CSV file
        csv_path = os.path.join(classification_folder, csv_file)
        
        # Read the CSV file
        results_df = pd.read_csv(csv_path)

        # Filter out images classified as "Detritus"
        filtered_df = results_df[results_df['Predicted_Label'] != "Detritus"]

        # If no images remain after filtering, skip to the next CSV file
        if filtered_df.empty:
            print(f"No non-Detritus images found in {csv_file}. Skipping...")
            continue

        # Sample 20 random images from the filtered DataFrame, or less if fewer than 20 non-Detritus images exist
        random_sample = filtered_df.sample(n=min(20, len(filtered_df)), random_state=42)  # random_state ensures reproducibility

        # Create the plot
        plt.figure(figsize=(25, 10))

        for i, (index, row) in enumerate(random_sample.iterrows()):
            # Get the image path and predicted label
            image_path = row['Image_Path']
            predicted_label = row['Predicted_Label']

            # Load the image from the .npy file
            image = np.load(image_path)

            # Plot the image
            plt.subplot(4, 5, i + 1)  # 4 rows, 5 columns grid
            plt.imshow(image, cmap='gray')  # Assuming the image is grayscale
            plt.title(f"Predicted: {predicted_label}")
            plt.axis('off')

        plt.tight_layout()

        # Extract the base name (without the "_processed_classification_results.csv" part)
        base_name = csv_file.split("_processed_classification_results.csv")[0]

        # Define the path to save the PNG file
        output_png_path = os.path.join(classification_folder, f"{base_name}_non_det.png")

        # Save the plot as a PNG file
        plt.savefig(output_png_path)
        plt.close()  # Close the plot to free up memory

        print(f"Random 20 non-Detritus images plot saved as {output_png_path}")

# %% [markdown]
# ### **STEP-6 Merge the CSV files per Day**<br>
# **Step 6** merges all CSV files for a given day into one consolidated dataframe. It starts by locating all CSV files in the specified directory. Then, it reads each CSV file into a dataframe and appends them to a list. Finally, all the dataframes are concatenated into a single dataframe, which contains all the classification results for that day.

# %%
# STEP 6 merge the all csv files per day
import os
import pandas as pd
import glob

# Directory containing the CSV files
csv_directory = r"D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_class_processed\classification_results_v2"#your folder path for classification results_v2 for the day D20250621

# Find all CSV files in the directory
csv_files = glob.glob(os.path.join(csv_directory, '*.csv'))

# List to hold dataframes from each CSV file
df_list = []

# Iterate over each CSV file and read it into a dataframe
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    df_list.append(df)

# Concatenate all dataframes into one
merged_df = pd.concat(df_list, ignore_index=True)

# %% [markdown]
# ### **STEP-7 Summarize the Results of Classifier per Day**<br>
# **Step 7** sums up the predicted labels by counting how often each label appears in the Predicted_Label column. It generates a summary dataframe with the label counts and saves it as a CSV file. You need to manually provide the desired output CSV file name in the output_path. This step helps you quickly review the distribution of predicted labels in the dataset.

# %%
#STEP 7 SUMMARIZE THE RESULTS
import pandas as pd

# Summarize the Predicted_Label column
label_summary = merged_df['Predicted_Label'].value_counts()

# Convert the summary to a DataFrame for saving as CSV
summary_df = label_summary.reset_index()
summary_df.columns = ['Predicted_Label', 'Count']

# Path to save the output CSV file
output_path = r"D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_labels_summary.csv"#your summary csv file change the name as you want

# Save the summary as a CSV file
summary_df.to_csv(output_path, index=False)

print(f"Summary saved at: {output_path}")
# Out:
# Summary saved at: D:\2025_Cruises\Jun25_AK_HABCruise-20250622T054844Z-1-002\Jun25_AK_HABCruise\D20250621\D20250621_labels_summary.csv
